# %%
from car import Car
from road import Road

# %%
road = Road(number_of_cars = 30)
road.place_cars()

# for car in road.set_of_cars:
#     print(car.car_coordinates)

# %%
# speed_data = []
# position_data = []

# for _ in range(60):
#     for index, car in enumerate(road.set_of_cars):

#         td = road.set_tail_distance(car, road.set_of_cars[index-1])
#         car.set_new_speed(road.set_of_cars[index-1], td)
#         car.change_position()
#         road.check_position(car, road.set_of_cars[index-1])
#         road.check_end_of_lap(car)

#         if _ > 60/2:
#             speed_data.append(car.speed)
#         print(car.car_coordinates)
#         position_data.append(car.car_coordinates)

speed_data, positions_data = road.simulate_n_seconds(60)
print(positions_data)
# Out:
# [array([ 997,  998,  999, 1000, 1001]), array([930, 931, 932, 933, 934]), array([897, 898, 899, 900, 901]), array([860, 861, 862, 863, 864]), array([831, 832, 833, 834, 835]), array([798, 799, 800, 801, 802]), array([765, 766, 767, 768, 769]), array([732, 733, 734, 735, 736]), array([699, 700, 701, 702, 703]), array([666, 667, 668, 669, 670]), array([629, 630, 631, 632, 633]), array([600, 601, 602, 603, 604]), array([567, 568, 569, 570, 571]), array([534, 535, 536, 537, 538]), array([501, 502, 503, 504, 505]), array([468, 469, 470, 471, 472]), array([435, 436, 437, 438, 439]), array([402, 403, 404, 405, 406]), array([369, 370, 371, 372, 373]), array([336, 337, 338, 339, 340]), array([303, 304, 305, 306, 307]), array([270, 271, 272, 273, 274]), array([237, 238, 239, 240, 241]), array([204, 205, 206, 207, 208]), array([171, 172, 173, 174, 175]), array([134, 135, 136, 137, 138]), array([105, 106, 107, 108, 109]), array([72, 73, 74, 75, 76]), array([39, 40, 41, 42, 43]), array([ 6,  7,  
# ...
